# %% [markdown]
# ## MSDS 7331: Data Mining
#
# ## Lab 3: Clustering
#
# ## 11 August 2019
#
# ## Authors: Meredith Ludlow, Anand Rajan, Kristen Rollins, and Tej Tenmattam
#
# ---

# %% [markdown]
# # Business Understanding

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Rubric 1:</b> Describe the purpose of the data set you selected (i.e., why was this data
# collected in the first place?). How will you measure the effectiveness of a good algorithm? Why does your chosen validation method make sense for this specific dataset and the stakeholders needs?
# </div>

# %% [markdown]
# **Purpose of data set:**
# The Census Bureau presents census data from the entire United States including Puerto Rico and District of Columbia. The data consists of 5 year estimates from the 2017 American Community Survey. The data set contains 37 variables that measure features such as socio-economic status, race, and sex, and is produced for all counties. The data for the census was collected to have information on population distributions for the United States.
#
# **Algorithm effectiveness:**
# Our intentions for the data set are to be able to accurately predict unemployment rates and child poverty rates. If we can predict them, then we can see what variables contribute to an accurate prediction. Knowing what factors are associated with unemployment and child poverty can create a basis for what things can be changed to lower unemployment and child poverty. A good prediction algorithm will have a prediction accuracy of at least 80%. Because the data covers the whole United States, it is important to make accurate predictions so that those trying to bring about change can effectively and efficiently utilize resources in places where they are most needed.
#
# **Validation method and metrics:**
# To test and validate our models, we will use a stratified shuffle split to divide our data into training and testing sets. Stratification is appropriate for our dataset as a precautionary measure. Our target binary class variables of unemployment and child poverty are already split close to 50/50, but using stratification ensures that this ratio is maintained and not skewed by random chance. In addition, we will use a 80/20 train/test split because we have a fairly large amount of data (70k+ observations). For large datasets, is it appropriate to use a smaller percentage for the test set because there is still plenty to test on, whereas a smaller dataset might necessitate a 60/40 or even a 50/50 train/test split.
#
# The primary evaluation metric we will use for our classification tasks is accuracy, but we will examine precision and recall as well. Accuracy is already a good metric for our dataset, because there is no class imbalance. We will define our target class variables to be split such that half of the observations are considered to have high unemployment and half have low unemployment, and we will make a similar split for child poverty. Thus if we see accuracies much higher than 50%, this is a good indication that the models are performing well.
#
# Precision and recall are also helpful to us based on the stakeholders who might be using these models. If a model attains high precision, i.e. there are few false positives, this means that the model did not flag many census tracts that actually had low unemployment or child poverty as ones needing aid. High precision would be good for an organization that has limited resources, i.e. they can only help so many neighborhoods, so they want to make sure the ones they target are actually in need of economic development or aid.
#
# On the other hand, if a model has high recall, i.e. there are few false negatives, this means that when census tracts have high unemployment or child poverty the model correctly identifies them. This would be appropriate for an organization that has extensive resources that wants to aid in all areas that need it, or at least identify/flag all of those areas for future development. Therefore we will look at accuracy, precision and recall for our classification tasks.

# %% [markdown]
# # Data Understanding 1

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Rubric 2:</b> Describe the meaning and type of data (scale, values, etc.) for each
# attribute in the data file. Verify data quality: Are there missing values? Duplicate data?
# Outliers? Are those mistakes? How do you deal with these problems?
# </div>

# %% [markdown]
# ### Data Meaning and Type

# %% [markdown]
# We selected the 2017 Census data taken from the American Community Survey, located on [Kaggle](https://www.kaggle.com/muonneutrino/us-census-demographic-data). It has data from the entire U.S. and can be used for analysis and providing interesting insights. Full sets of data are found on the American fact finder website. We will be using the file named acs2017_census_data.csv for our analysis. The data has 37 variables and 74,001 rows. We will be utilizing all of the data for our analysis. We will be using important attributes that can be used to predict unemployment and child poverty. The attribute definitions are as follows:

# %% [markdown]
# | Attribute | Data Type | Description |
# |-----------|-----------|-------------|
# | TractID | Nominal | Unique identification number for the census tract <br/> (A tract is a geographic area, comparable to a neighborhood, <br/> defined for the purpose of taking a census.) |
# | State | Nominal | U.S. state or territory the tract is located in |
# | County | Nominal | County or county-equivalent the tract is located in |
# | TotalPop | Integer | Total population of the census area |
# | Men | Integer | Number of men living in the census tract |
# | Women | Integer | Number of women living in the census tract |
# | Hispanic | Decimal | Percentage of population that is Hispanic/Latino |
# | White | Decimal | Percentage of population that is white |
# | Black | Decimal | Percentage of population that is black |
# | Native | Decimal | Percent of population that is Native American |
# | Asian | Decimal | Percent of population that is Asian |
# | Pacific | Decimal | Percent of population that is Native Hawaiian or other Pacific Islander |
# | VotingAgeCitizen | Integer | Number of voting age citizens in the census tract |
# | Income | Decimal | Median household income in USD (\$) |
# | IncomeErr | Decimal | Median household income error (\$) |
# | IncomePerCap | Decimal | Income per capita (\$) |
# | IncomePerCapErr | Decimal | Income per capita error (\$) |
# | Poverty | Decimal | Percentage of population under the poverty level |
# | ChildPoverty | Decimal | Percentage of children under the poverty level |
# | Professional | Decimal | Percent employed in management, business, science, and arts |
# | Service | Decimal | Percent employed in service jobs |
# | Office | Decimal | Percent employed in sales and office jobs |
# | Construction | Decimal | Percent employed in natural resources, construction, and maintenance |
# | Production | Decimal | Percent employed in production, transportation, and material movement |
# | Drive | Decimal | Percent commuting alone in a car, van, or truck |
# | Carpool | Decimal | Percent carpooling in a car, van, or truck |
# | Transit | Decimal | Percent commuting on public transportation |
# | Walk | Decimal | Percent walking to work |
# | OtherTransp | Decimal | Percent commuting via other means |
# | WorkAtHome | Decimal | Percentage working at home |
# | MeanCommute | Decimal | Mean commute time in minutes |
# | Employed | Integer | Number of people employed (16+) |
# | PrivateWork | Decimal | Percentage employed in private industry |
# | PublicWork | Decimal | Percentage employed in public jobs |
# | SelfEmployed | Decimal | Percentage self-employed
# | FamilyWork | Decimal | Percentage in unpaid family work |
# | Unemployed | Decimal | Unemployment rate (%) |

# %% [markdown]
# ### Data Quality

# %% [markdown]
# Before jumping into analysis, it is important for us to verify the quality of our data. After importing various libraries and our dataset, we first verified that there were no duplicates by checking the uniqueness of the TractID field. Because this field was stated to be an identifier for each geographic area of the census, we assumed that there would be no duplicates; we confirmed this to be safe.
#
# We also viewed missing values occuring in each column. Upon investigation, we found that many NaNs were occuring because several tracts had a population of 0, leading to invalid percentages for other variables. These missing values were not mistakes in the data, because it is possible for census tracts to be unpopulated. However, it does not make sense to predict poverty or unemployment rates for empty areas, so we chose to remove these observations. To deal with the remaining missing values, we performed imputation to the median, some aggregated over another variable. We favored the median over the mean because the median is not heavily influenced by outliers.
#
# Finally, to identify potential outliers we looked at summary statistics of our numeric variables. While it is difficult to detect outliers in such a high-dimensional space, in this way we could identify out of the ordinary minimums and maximums, especially with so many percentage attributes. For instance, if a percentage variable had a minimum less than 0 or maximum greater than 100, this would certainly have been an error in the data. We did not observe any mistakes such as this, and we felt that the non-percentage variables had reasonable statistics as well. Therefore we did not remove any outliers.

# %%
# importing necessary packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# Set seaborn plot styles
sns.set_style('darkgrid')
sns.set_color_codes('muted')

import warnings
warnings.filterwarnings("ignore") # ignore warnings for clean report

# df.head() displays all the columns without truncating
pd.set_option('display.max_columns', None)

# read csv file as pandas dataframe
df_17_census = pd.read_csv('../Data/acs2017_census_tract_data.csv')

# %%
# Clean dataset as in lab 1
print("Duplicate data:", not df_17_census['TractId'].is_unique) # check for duplicate data
df_17_census.set_index('TractId', inplace=True) # set tract id as index

# Drop tracts where population is 0
df_17_cln = df_17_census.drop(df_17_census[df_17_census.TotalPop == 0].index)

# Drop tracts where child poverty or unemployment is null
df_17_cln = df_17_cln[np.isfinite(df_17_cln['ChildPoverty'])]
df_17_cln = df_17_cln[np.isfinite(df_17_cln['Unemployment'])]

# Impute to the median by each state
df_grouped = df_17_cln.groupby('State').transform(lambda x: x.fillna(x.median()))
df_17_cln['Income'] = df_grouped['Income']
df_17_cln['IncomeErr'] = df_grouped['IncomeErr']

# Impute remaining values to the overall median
df_17_cln = df_17_cln.fillna(df_17_cln.median())
# Out:
# Duplicate data: False

# %%
# Categorize the unemployed percentages into binary categories
# Make cutoff using median of clean dataset, so groups are roughly equal
df_17_cln['HighUnemployment'] = pd.cut(df_17_cln.Unemployment,[-1,6,101],labels=[0,1])     
df_17_cln.HighUnemployment = df_17_cln.HighUnemployment.astype(np.int)
# 0 indicates low unemployment rate, 1 indicates high unemployment rate

# Categorize the child poverty percentages into binary categories
# Make cutoff using median of clean dataset, so groups are roughly equal
df_17_cln['HighChildPoverty'] = pd.cut(df_17_cln.ChildPoverty,[-1,16.3,101],labels=[0,1])
df_17_cln.HighChildPoverty = df_17_cln.HighChildPoverty.astype(np.int)
# 0 indicates low child poverty rate, 1 indicates high child poverty rate

df_17_cln.describe() # check for outliers
# Out:
#            TotalPop           Men         Women      Hispanic         White  \
# count  72889.000000  72889.000000  72889.000000  72889.000000  72889.000000
# mean    4438.372759   2182.350698   2256.022061     17.290081     61.312817
# std     2192.532931   1101.516460   1126.275010     23.097490     30.635700
# min        4.000000      0.000000      0.000000      0.000000      0.000000
# 25%     2953.000000   1438.000000   1491.000000      2.600000     38.100000
# 50%     4133.000000   2022.000000   2100.000000      7.400000     70.400000
# 75%     5530.000000   2717.000000   2815.000000     21.100000     87.700000
# max    65528.000000  32266.000000  33262.000000    100.000000    100.000000
#
#               Black        Native         Asian       Pacific  \
# count  72889.000000  72889.000000  72889.000000  72889.000000
# mean      13.268165      0.729703      4.752853      0.146698
# std       21.598962      4.525143      8.992743      1.023074
# ...

# %%
df_17_cln.info() # matches cleaned dataset from lab 1
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 72889 entries, 1001020100 to 72153750602
# Data columns (total 38 columns):
# State               72889 non-null object
# County              72889 non-null object
# TotalPop            72889 non-null int64
# Men                 72889 non-null int64
# Women               72889 non-null int64
# Hispanic            72889 non-null float64
# White               72889 non-null float64
# Black               72889 non-null float64
# Native              72889 non-null float64
# Asian               72889 non-null float64
# Pacific             72889 non-null float64
# VotingAgeCitizen    72889 non-null int64
# Income              72889 non-null float64
# IncomeErr           72889 non-null float64
# IncomePerCap        72889 non-null float64
# IncomePerCapErr     72889 non-null float64
# Poverty             72889 non-null float64
# ChildPoverty        72889 non-null float64
# Professional        72889 non-null float64
# ...

# %%
#Dimensions of our cleaned dataset
print("Shape of cleaned dataset:", df_17_cln.shape)
print("Observations removed:", df_17_census.shape[0]-df_17_cln.shape[0])
# Out:
# Shape of cleaned dataset: (72889, 38)
# Observations removed: 1112

# %%
# Create dataframe to use in models
df_17_model = df_17_cln.copy()

# Eliminate non-useful and redundant variables
del df_17_model['State'] # encoding would result in too many added variables
del df_17_model['County'] # encoding would result in too many added variables
del df_17_model['Men'] # redundant to keep men and women
del df_17_model['Unemployment'] # already encoded to binary
del df_17_model['ChildPoverty'] # already encoded to binary

# Eliminate more variables based on correlation plot (could maybe remove more)
del df_17_model['IncomeErr'] # only need to keep one income-related variable
del df_17_model['IncomePerCap'] # only need to keep one income-related variable
del df_17_model['IncomePerCapErr'] # only need to keep one income-related variable
del df_17_model['Transit'] # drive and transit were essentially inverses
del df_17_model['PublicWork'] # private and public work were essentially inverses

# All remaining variables are ints or floats so we do not have to do one-hot encoding

# Convert columns to percentages for consistency
df_17_model['Women'] = round(df_17_model['Women']/df_17_model['TotalPop']*100,1)
df_17_model['VotingAgeCitizen'] = round(df_17_model['VotingAgeCitizen']/df_17_model['TotalPop']*100,1)
df_17_model['Employed'] = round(df_17_model['Employed']/df_17_model['TotalPop']*100,1)

print(df_17_model.info())
df_17_model.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 72889 entries, 1001020100 to 72153750602
# Data columns (total 28 columns):
# TotalPop            72889 non-null int64
# Women               72889 non-null float64
# Hispanic            72889 non-null float64
# White               72889 non-null float64
# Black               72889 non-null float64
# Native              72889 non-null float64
# Asian               72889 non-null float64
# Pacific             72889 non-null float64
# VotingAgeCitizen    72889 non-null float64
# Income              72889 non-null float64
# Poverty             72889 non-null float64
# Professional        72889 non-null float64
# Service             72889 non-null float64
# Office              72889 non-null float64
# Construction        72889 non-null float64
# Production          72889 non-null float64
# Drive               72889 non-null float64
# Carpool             72889 non-null float64
# Walk                72889 non-null float64
# ...

# %%
# create X and y variables to use in models
# y_u is for unemployment, y_cp is for child poverty
if 'HighUnemployment' in df_17_model:
    y_u = df_17_model['HighUnemployment'].values # get the labels we want
    del df_17_model['HighUnemployment'] # get rid of the class label
if 'HighChildPoverty' in df_17_model:
    y_cp = df_17_model['HighChildPoverty'].values # get the labels we want
    del df_17_model['HighChildPoverty'] # get rid of the class label
X = df_17_model.values # use everything else to predict

# %% [markdown]
# # Data Understanding 2

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Rubric 3:</b> Visualize any important attributes appropriately. Important: Provide an
# interpretation for any charts or graphs.
# </div>

# %% [markdown]
# #### HighUnemployment and HighChildPoverty
#
# It is first helpful to examine our target variables of HighUnemployment and HighChildPoverty. The plot below indicates that the frequency distribution of the HighUnemployment label is almost equally distributed among the population.
# This is to simplify and balance the categorical variable for our models.

# %%
# Histogram for HighUnemployment
df_17_cln.HighUnemployment.plot.hist(stacked=True, bins=8);

# %% [markdown]
# Similarly, the histogram below shows that the census tracts are almost equally distributed between high and low child poverty. This occurs because we created the labels based on the median child poverty rate, in order to have balanced classification tasks.

# %%
# Histogram for HighChildPoverty
df_17_cln.HighChildPoverty.plot.hist(stacked=True, bins=8);

# %% [markdown]
# We can now examine the relationships between our target variables and other important variables.

# %% [markdown]
# #### Correlation of Unemployment to Poverty (linear regression with marginal distributions)

# %%
#Correlation join plot for unemployment and poverty 
df_jp = pd.pivot_table(df_17_cln, values=["Unemployment","Poverty"], index="State", aggfunc=np.mean)
g = sns.jointplot(data=df_jp, kind="reg", xlim=(0,60), ylim=(0,12), color = "m",
                  y='Unemployment', x='Poverty')

# %% [markdown]
# In the scatterplot above the correlation between Unemployment and Poverty is seen for each state. The two variables are quite normal in terms of distribution as seen in the histogram on the x and y axes. We see that state-wise poverty and unemployment levels have a positive, moderately strong linear relationship. This is intuitive because as more people become unemployed, more will fall into poverty. The slope of the line is interesting, however, because it is not a one-to-one relationship (note the x and y scales). Unemployment increases at a slower rate than poverty, implying that there are many people who are under the poverty level while actually being employed.

# %% [markdown]
# #### Correlation of Unemployment to Child Poverty (linear regression with marginal distributions)

# %%
#Correlation join plot for unemployment and child poverty 
df_jp = pd.pivot_table(df_17_cln, values=["Unemployment","ChildPoverty"], index="State", aggfunc=np.mean)
g = sns.jointplot(data=df_jp, kind="reg", xlim=(0,60), ylim=(0,12), color = "g",
                  y='Unemployment', x='ChildPoverty')

# %% [markdown]
# When comparing the unemployment rate to the child poverty rate, we see that the slope is about 1/5. The slope for unemployment versus poverty is approximately 2/5. Child poverty increases even more rapidly compared to unemployment than poverty does. This makes sense because children are expensive and families with more children are more likely to be in poverty even if they are still employed than families without children.

# %% [markdown]
# #### Histogram of Race Percentages
#
# From the histogram below, we see that there are many tracts with low black and hispanic populations, seen by their pronounced right-skew. In contrast, there are consistently more tracts having high white populations. This is reflected in a summary table for our data, where we saw that the median for white populations is 87.7% while the mean is pulled down to 61.3% by the distribution. We expect that these racial breakdowns will influence our predictions on child poverty and unemployment.

# %%
# Overlayed histograms of 3 most populous races
fig, ax = plt.subplots()
fig.set_size_inches(11, 6)
sns.distplot(df_17_model["Hispanic"], label="Hispanic", ax=ax)
sns.distplot(df_17_model["White"], label="White", ax=ax)
sns.distplot(df_17_model["Black"], label="Black", ax=ax)
plt.legend()
plt.title('Density histogram of 3 populous races')
plt.xlabel('Density');
plt.ylabel('Race percentage');

# %% [markdown]
# #### Relationships between Unemployment and Race

# %% [markdown]
# Furthermore, as can be seen from the three scatterplots below, the Unemployment rate and the ethnic/racial group percentage shows a strong correlation. While the points are rather dense, there are clear patterns in the data indicating that the unemployment rate is correlated either in a positive or negative direction depending on the ethnic/racial breakdown of a particular community. In particular, as the white population increases, the unemployment rate decreases. Conversely, as the black and Hispanic populations increase, unemployment increases. Notably, unemployment increases at a faster rate for black populations when compared to Hispanic populations.

# %%
# Graph for unemployment versus percentage of white people.
sns.set_style("whitegrid")
sns.set_context(rc = {'patch.linewidth': 1})
sns.jointplot(x='White', y='Unemployment', data=df_17_cln, kind='reg',scatter_kws={'color':'c'}, size=8);

# %%
# Graph for unemployment versus percentage of black people
sns.jointplot(x='Black', y='Unemployment', data=df_17_cln, kind='reg', scatter_kws={'color':'c'}, size=8);

# %%
# Graph for unemployment versus percentage of hispanic people
sns.jointplot(x='Hispanic', y='Unemployment', data=df_17_cln, kind='reg', scatter_kws={'color':'c'}, size=8);

# %% [markdown]
# # Modeling and Evaluation

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Rubric 4:</b> Different tasks will require different evaluation methods. Be as thorough as possible when analyzing the data you have chosen and use visualizations of the results to explain the performance and expected outcomes whenever possible. Guide the reader through your analysis with plenty of discussion of the results.
# </div>

# %% [markdown]
# ## Cluster Analysis

# %% [markdown]
# <div class="alert alert-block alert-info">
#
#
#
# - Perform cluster analysis using several clustering methods.
# - How did you determine a suitable number of clusters for each method?
# - Use internal and/or external validation measures to describe and compare the clusterings and the clusters (some visual methods would be good).
# - Describe your results. What findings are the most interesting and why?
# </div>

# %% [markdown]
# Clustering is one of the methods of unsupervised learning used to visualize and group data in to similar groups. Structure and patterns in data can be visualized with clustering and is immensely useful in data science projects. We have chosen to perform cluster analysis to gain further insights into the characteristics of our census data as well as attempt to improve the performance of our predictive models.
#
# Our overall approach is to first run a logistic model to determine the top features of our dataset, to reduce dimensionality before performing cluster analysis. We then run several clustering algorithms on this reduced dataset to reveal characteristics of the dataset. We finally use multiple clustering methods to further reduce the dimensions and then use those clusters as variables in our classification models.

# %% [markdown]
# ### Evaluating feature importance using SGD
#
# In this part we do the training and update the model weights. The hyper parameter "learning rate" is set. It can neither be too small or too large so as to reach the minimum of the loss function.
# We can use values between 0 and 1 (randomly) and minimize loss and maximize prediction. If the difference between the last values of cost is less than the threshold, then we stop updating.
# The below code actually standardizes the scale and brings about the top 8 features that are important for our clustering analysis.

# %%
# Standard scaler used to scale the variables.
# Following code from Dr. Larson's Logits and SVM notebook
from sklearn.model_selection import ShuffleSplit
from sklearn.preprocessing import StandardScaler
scl_obj = StandardScaler()

# we want to predict the X and y data as follows:
if 'HighUnemployment' in df_17_model:
    y_u = df_17_model['HighUnemployment'].values # get the labels we want
    del df_17_model['HighUnemployment'] # get rid of the class label
    X = df_17_model.values # use everything else to predict

# 10 fold cross-validation
num_cv_iterations = 10
num_instances = len(y_u)
cv_object = ShuffleSplit(n_splits=num_cv_iterations, test_size  = 0.2)
                         
print(cv_object)

for iter_num, (train_indices, test_indices) in enumerate(cv_object.split(X,y_u)):
    # scale attributes by the training set
    scl_obj.fit(X[train_indices])
    X_train_scaled = scl_obj.transform(X[train_indices]) # apply to training
    X_test_scaled = scl_obj.transform(X[test_indices]) # use training scales to adjust test set, so we're not cheating
    y_test_u = y_u[test_indices]
# Out:
# ShuffleSplit(n_splits=10, random_state=None, test_size=0.2, train_size=None)

# %%
from sklearn.linear_model import SGDClassifier

#Features most important using Logistic regression
#The best hyperparameter offered a log loss of .675 and accuracy of 73% which is somewhat good.

SGD = SGDClassifier(loss="log", penalty = "l2", max_iter=500, tol=1e-3)
SGD.fit(X_train_scaled,y_u[train_indices])

coefs = np.abs(SGD.coef_[0])
indices = np.argsort(coefs)[::-1]

plt.figure(figsize=(10,8))
plt.title("Feature importances (SGD)")
num_features = 8
plt.bar(range(num_features), coefs[indices[:num_features]],
       color="r", align="center")
plt.xticks(range(num_features), df_17_model.columns[indices[:num_features]], rotation=45, ha='right')
plt.subplots_adjust(bottom=0.3)

plt.ion(); plt.show()

# %% [markdown]
# #### Top features for clustering
#
# We determined these features in the graph above to be the most important in influencing High Unemployment and High Child Poverty. Moving forward, we will only use these top 8 variables in our clustering and predictive models, in order to protect against overfitting and to improve clustering performance.

# %%
from matplotlib import pyplot as plt
plt.style.use("ggplot")

# %matplotlib inline

X1 = df_17_cln[['HighUnemployment','HighChildPoverty']].values

plt.scatter(X1[:, 0]+np.random.random(X1[:, 0].shape), X1[:, 1]+np.random.random(X1[:, 1].shape), 
             s=0.7)
plt.xlabel('HighUnemployment'), plt.ylabel('HighChildPoverty')
plt.grid()
plt.title('Unemployment versus Child Poverty')
plt.show()

# %% [markdown]
# #### Inference from the plot
#
# We see with the selected labels for prediction the two target variables are totally correlated. Both equally complement one another and we could say if we predict unemployment, most probably if the family has a child, it undergoes poverty.

# %%
sns.set(rc={'figure.figsize':(8,8)})

corr = df_17_model[['White','Employed','Hispanic','Poverty','Black','Service','MeanCommute','VotingAgeCitizen']].corr()
sns.heatmap(corr, annot=True,
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values)
plt.title('Heat Map for 8 important features');

# %% [markdown]
# #### Correlation Heatmap
# The heatmap indicates the level of correlated attributes. We can safely tell that the features selected for prediction of Unemployment and/or Child poverty are influencing the outcome.

# %%
# Standard scaler used to scale the variables.
# also scale variables
# Following code from Dr. Larson's Logits and SVM notebook
from sklearn.model_selection import ShuffleSplit
from sklearn.preprocessing import StandardScaler
from time import time
scl_obj = StandardScaler()

X = df_17_model[['White','Employed','Hispanic','Poverty','Black','Service','MeanCommute','VotingAgeCitizen']].values # use importatnt features
# we want to predict the X and y data as follows:
if 'HighUnemployment' in df_17_model:
    y_u = df_17_model['HighUnemployment'].values # get the labels we want
    del df_17_model['HighUnemployment'] # get rid of the class label
    
# 10 fold cross-validation
num_cv_iterations = 10
num_instances = len(y_u)
cv_obj = ShuffleSplit(n_splits=num_cv_iterations, test_size  = 0.2)
                         
print(cv_obj)

for iter_num, (train_ind, test_ind) in enumerate(cv_obj.split(X,y_u)):
    # scale attributes by the training set
    scl_obj.fit(X[train_ind])
    X_train_sc = scl_obj.transform(X[train_ind]) # apply to training
    X_test_sc = scl_obj.transform(X[test_ind]) # use training scales to adjust test set, so we're not cheating
    y_test_u = y_u[test_ind]
# Out:
# ShuffleSplit(n_splits=10, random_state=None, test_size=0.2, train_size=None)

# %% [markdown]
# ## Desirable Properties of Clusters:

# %% [markdown]
# Now that we have a reduced dataset, we will perform clustering as an exploratory technique. Note that for the metrics that required labeled data, we will use only the HighUnemployment attribute, since we found that HighUnemployment and HighChildPoverty are so closely related. Some of the desirable properties of clusters are:
#
# **Homogeneity:** Each cluster should contain members of the same class.
#
# **Completeness:** All members of a class should lie in the same cluster.
# Homogeneity and completeness are inversely related. Each lies between 0 and 1 (higher is better). They are similar to precision and recall.
#
# **V-measure:** is the harmonic mean of homogeneity and completeness. Homogeneity, Completeness and V-measure are related set of metrics. They have bounded scores between 0 and 1. They are easy to interpret - higher is better. They are easy to apply to any algorithm, however they require labeled data.
#
# **Adjusted Rand Index:** is a measure of similarity between labels and assigned clusters. This also needs labeled data and adjusts for probability of correct labeling by chance. It is named after William Rand. Takes value between -1 and 1 in sklearn. 1 indicates that labels and calculated clusters agree perfectly for all points, 0 or negative values are bad which indicate that labels and calculated clusters are independent.
#
# **Adjusted Mutual Info:** measures mutual information in overlap between cluster assignments. This also needs labeled data. 1 indicates highest mutual information, i.e. best clustering. 0 or negative values are bad which indicate that labels and calculated clusters are independent.
#
# **Silhouette Score:** defines Silhouette coefficient for each sample. This is a measure of how similar an object is to objects in its own cluster, and how different it is from objects in other clusters. Overall Silhouette score averages Silhouette coefficient of each sample. There is no need for labeled data.

# %%
from sklearn import metrics
from sklearn.cluster import KMeans
from sklearn.cluster import AgglomerativeClustering
from sklearn.cluster import DBSCAN
from sklearn.cluster import MeanShift
from sklearn.cluster import Birch
from sklearn.cluster import AffinityPropagation
from sklearn.cluster import MiniBatchKMeans
from sklearn.metrics import silhouette_score
from sklearn.model_selection import ParameterGrid


import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# The first clustering method we will use is K-means, which requires us to specify the number of clusters to be produced. To determine the optimal number of clusters, we can graph the within-cluster sum-of-squares (WCSS) for several K clusters, and visually decide where the best trade off occurs.

# %%
# Using the elbow method to get the optimal number of clusters
from sklearn.cluster import KMeans
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state = 42)
    kmeans.fit(X_train_sc)
    wcss.append(kmeans.inertia_)
plt.plot(range(1, 11), wcss)
plt.title('The Elbow Method showing the optimal K')
plt.xlabel('K - Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %% [markdown]
# The elbow method suggests an optimal number of clusters at 2 or 3. Now let's confirm the optimal K using hyperparameter tuning.

# %%
# Hyperparameter Tuning
parameters = {'n_clusters': [2, 3, 4, 5, 6, 10, 20, 30]}
parameter_grid = ParameterGrid(parameters)
list(parameter_grid)
# Out:
# [{'n_clusters': 2},
#  {'n_clusters': 3},
#  {'n_clusters': 4},
#  {'n_clusters': 5},
#  {'n_clusters': 6},
#  {'n_clusters': 10},
#  {'n_clusters': 20},
#  {'n_clusters': 30}]

# %%
best_score = -1
model = KMeans()
for g in parameter_grid:
    model.set_params(**g)
    model.fit(X_train_sc)

    ss = metrics.silhouette_score(X_train_sc, model.labels_)
    print('Parameter: ', g, 'Score: ', ss)
    if ss > best_score:
        best_score = ss
        best_grid = g
# Out:
# Parameter:  {'n_clusters': 2} Score:  0.3653920780256919
# Parameter:  {'n_clusters': 3} Score:  0.381593445352626
# Parameter:  {'n_clusters': 4} Score:  0.19754601034378072
# Parameter:  {'n_clusters': 5} Score:  0.1824169975097855
# Parameter:  {'n_clusters': 6} Score:  0.16438223375127275
# Parameter:  {'n_clusters': 10} Score:  0.1494977382156846
# Parameter:  {'n_clusters': 20} Score:  0.1307125773383233
# Parameter:  {'n_clusters': 30} Score:  0.12271650526510954

# %%
best_grid
# Out:
# {'n_clusters': 3}

# %% [markdown]
# We have verified K=3 as the optimal number of clusters for K-means, so we will proceed.

# %%
def build_model(clustering_model, data, labels):
    
    model = clustering_model(data)

    print('clust\thomo\tcompl\tv-meas\tARI\tAMI\tsilhouette')
    print(60 * '-')
    lab = model.labels_
    n_clusters_ = len(set(lab)) - (1 if -1 in lab else 0)
    
    print('%d\t%.3f\t%.3f\t%.3f\t%.3f\t%.3f\t%.3f'
          %(n_clusters_,
            metrics.homogeneity_score(labels, model.labels_),
            metrics.completeness_score(labels, model.labels_),
            metrics.v_measure_score(labels, model.labels_),
            metrics.adjusted_rand_score(labels, model.labels_),
            metrics.adjusted_mutual_info_score(labels,  model.labels_),
            metrics.silhouette_score(data, model.labels_)))

# %%
# K-means clustering
def k_means(data, n_clusters=3, max_iter=1000):
    model = KMeans(n_clusters=n_clusters, max_iter=max_iter).fit(data)
    
    return model

# %%
# %%time
build_model(k_means, X_test_sc, y_test_u)
# Out:
# clust	homo	compl	v-meas	ARI	AMI	silhouette
# ------------------------------------------------------------
# 3	0.119	0.104	0.111	0.097	0.104	0.380
# CPU times: user 5.23 s, sys: 650 ms, total: 5.88 s
# Wall time: 4.16 s

# %%
# Fitting K-Means to the test dataset
kmeans = KMeans(n_clusters = 3, init = 'k-means++', random_state = 42)
y_kmeans = kmeans.fit_predict(X_test_sc)

# Scatter chart of the clusters
plt.scatter(X_test_sc[y_kmeans == 0, 0], X_test_sc[y_kmeans == 0, 1], s = 50, c = 'orchid', label = 'Cluster A')
plt.scatter(X_test_sc[y_kmeans == 1, 0], X_test_sc[y_kmeans == 1, 1], s = 50, c = 'c', label = 'Cluster B')
plt.scatter(X_test_sc[y_kmeans == 2, 0], X_test_sc[y_kmeans == 2, 1], s = 50, c = 'mediumspringgreen', label = 'Cluster C')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s = 200, c = 'red', label = 'Centroids')
plt.title('Clusters of Population')
plt.legend()
plt.show()

# %% [markdown]
# Here we have visualized the clusters that are produced by K-means, for just the first two attributes in the dataset. While we do see some separation, it is difficult to tell in only two dimensions if the clustering is appropriate. We trust that the hyperparameter tuning detected patterns in higher dimensions that we cannot visualize, and the choice of 3 clusters is actually appropriate.
#
# K-means is one of the most well-known clustering algorithms, but now we will run several additional algorithms to compare.

# %%
# Agglomerative Clustering
def agglomerative_fn(data, n_clusters=3):
    model = AgglomerativeClustering(n_clusters = n_clusters).fit(data)
    
    return model

# %%
# %%time
build_model(agglomerative_fn, X_test_sc, y_test_u)
# Out:
# clust	homo	compl	v-meas	ARI	AMI	silhouette
# ------------------------------------------------------------
# 3	0.066	0.055	0.060	0.046	0.055	0.245
# CPU times: user 15.5 s, sys: 1.46 s, total: 17 s
# Wall time: 16.2 s

# %%
# DBSCAN Clustering
def dbscan_fn(data, eps=0.5, min_samples=14):
    model = DBSCAN(eps=eps, min_samples=min_samples).fit(data)
    return model

# %%
# %%time
build_model(dbscan_fn, X_test_sc, y_test_u)
# Out:
# clust	homo	compl	v-meas	ARI	AMI	silhouette
# ------------------------------------------------------------
# 3	0.049	0.063	0.055	0.039	0.049	-0.162
# CPU times: user 4.98 s, sys: 644 ms, total: 5.62 s
# Wall time: 4.29 s

# %%
# MeanShift Clustering
def mean_shift_fn(data, bandwidth=0.85):
    model = MeanShift(bandwidth=bandwidth).fit(data)
    return model

# %%
# %%time
build_model(mean_shift_fn, X_test_sc, y_test_u)
# Out:
# clust	homo	compl	v-meas	ARI	AMI	silhouette
# ------------------------------------------------------------
# 2791	0.356	0.042	0.075	0.025	0.021	-0.006
# CPU times: user 3min 54s, sys: 2.99 s, total: 3min 57s
# Wall time: 4min 5s

# %%
# Birch Clustering
def birch_fn(data, n_clusters=3):
    model = Birch(n_clusters=n_clusters).fit(data)
    return model

# %%
# %%time
build_model(birch_fn, X_test_sc, y_test_u)
# Out:
# clust	homo	compl	v-meas	ARI	AMI	silhouette
# ------------------------------------------------------------
# 3	0.096	0.077	0.086	0.090	0.077	0.325
# CPU times: user 7.59 s, sys: 1.14 s, total: 8.73 s
# Wall time: 7.29 s

# %%
# Affinity Propagation Clustering
def affinity_propagation_fn(data, damping=0.6, max_iter=1000):
    model = AffinityPropagation(damping=damping, max_iter=max_iter).fit(data)
    return model

# %%
# %%time
build_model(affinity_propagation_fn, X_test_sc, y_test_u)
# Out:
# clust	homo	compl	v-meas	ARI	AMI	silhouette
# ------------------------------------------------------------
# 429	0.261	0.031	0.056	0.002	0.029	0.098
# CPU times: user 20min 9s, sys: 51min 4s, total: 1h 11min 14s
# Wall time: 1h 46min 27s

# %%
# Mini Batch KMeans Clustering
def mini_batch_kmeans_fn(data, n_clusters=3, max_iter=1000):
    model = MiniBatchKMeans(n_clusters=n_clusters, max_iter=max_iter, batch_size=20).fit(data)
    return model

# %%
# %%time
build_model(mini_batch_kmeans_fn, X_test_sc, y_test_u)
# Out:
# clust	homo	compl	v-meas	ARI	AMI	silhouette
# ------------------------------------------------------------
# 3	0.119	0.103	0.110	0.098	0.103	0.376
# CPU times: user 5.3 s, sys: 767 ms, total: 6.07 s
# Wall time: 5.03 s

# %% [markdown]
# #### Model Comparison

# %% [markdown]
# | Model | # Clusters Est | Homogeneity | Completeness | V-Measure | Adjusted Rand | Adjusted Mutual Info | Silhouette  |
# | ----- |----------- | --------    | ---------    | --------- | ---------     | ---------            | ---------   |
# | K-means (K=3) | 3	  | 0.119	| 0.104	| 0.111	| 0.097	| 0.104	| 0.380  |
# | Agglomerative | 3	  | 0.066	| 0.055	| 0.060	| 0.046	| 0.055	| 0.245  |
# | DBSCAN        | 3	  | 0.049	| 0.063	| 0.055	| 0.039	| 0.049	|-0.162  |
# | MeanShift     | 2791| 0.356	| 0.042	| 0.075	| 0.025	| 0.021	|-0.006  |
# | Birch         | 3	  | 0.096	| 0.077	| 0.086	| 0.090	| 0.077	| 0.325  |
# | Affinity Prop | 429 |	0.261	| 0.031	| 0.056	| 0.002	| 0.029	| 0.098  |
# | Mini Batch    | 3	  | 0.119	| 0.103	| 0.110	| 0.098	| 0.103	| 0.376  |

# %% [markdown]
# Overall, the metrics do not indicate a clear winner between the 7 clustering techniques performed, though some models do have advantages over others. Looking at homogeneity, the MeanShift algorithm has the highest value at 0.356, but it has a very bad silhouette score at -0.006. The Affinity Propagation method has the next highest homogeneity at 0.261, but again has a fairly poor silhouette score of 0.098. Interesting, both of these algorithms produced many more clusters than any of the other methods (2791 and 429 respectively), which likely aided in their higher homogeneity. However, these large amount of clusters are inappropriate when we were seeking to replicate the binary division between high and low unemployment rates. But with more small but homogeneous small clusters, these models could be used to examine the dataset at a more granular level.
#
# The remaining clustering methods were specified to produce 3 clusters (besides DBSCAN, which produced 3 clusters on its own), based on hyperparameter tuning. Among these, K-means and Mini Batch K-means stand out as the most effective clusterings, as they have the greatest homogeniety and highest silhouette scores of any of the algorithms. Since we were aiming to replicate the "true" labels of high/low unemployment, we would have expected parameter tuning of the algorithms to produce only 2 clusters. So it is notable that 3 clusters were selected, suggesting that either the high unemployment or the low unemployment group can be divided up further by some other characteristic attribute. Furthermore, while unemployment rate was the attribute we were interested in, the relatively low metrics overall indicate that this may not be the most characteristic features of neighborhoods, and some other feature would be more appropriate as a neighborhood's "label."

# %% [markdown]
# ## Clustering in Predictive Models

# %% [markdown]
# Above, we created and examined clusters consisting of all variables from our dataset and compared them against the target variable of high unemployment. While this is an interesting way to explore characteristics of our dataset, another useful approach is to use clustering as a dimension reduction technique, and use the clusters produced as new variables in a classification model.

# %% [markdown]
# #### Random Forest accuracy for 8 fields to predict Unemployment
#
# In previous work, we found that a Random Forest model was the best performing model for classifying our dataset. Therefore, we will first run a Random Forest model using the top 8 important features that influence High Unemployment and High ChildPoverty. We will then perform various clustering methods to combine some of these features, and compare the model's performance while using these combined attributes as new variables.

# %%
from sklearn.model_selection import StratifiedKFold, cross_val_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

# Create dataframe to use in models
df_17_model2 = df_17_cln.copy()


X = df_17_model2[['White','Employed','Hispanic','Poverty','Black','Service','MeanCommute','VotingAgeCitizen']].values # use importatnt features
# we want to predict the X and y data as follows:
y_u = df_17_model2['HighUnemployment'].values # get the labels we want

    

X_train, X_test, y_train, y_test=train_test_split(X,y_u,random_state=101,test_size=0.2)
    
cv = StratifiedKFold(n_splits=10)

clf = RandomForestClassifier(n_estimators=150,random_state=1)
    
acc = cross_val_score(clf,X_train,y=y_train,cv=cv)

print ("Average accuracy = ", acc.mean()*100, "+-", acc.std()*100)
# Out:
# Average accuracy =  73.3840882031825 +- 0.5867898736796078

# %% [markdown]
# So we have 73.4% as our baseline accuracy.

# %% [markdown]
# #### Kmeans clustering using 8 features
#
# We will use the features selected above in the Random forest classsifier to do clustering using K-Means. The accuracy can be compared to see which model gives better predictive power.

# %%
# Group 1 kmeans.
from sklearn.cluster import KMeans
import numpy as np
import pandas as pd


X1 = df_17_model2[['White','Hispanic','Black','Poverty']]

cls = KMeans(n_clusters=4, init='k-means++',random_state=1)
cls.fit(X1)
newfeature = cls.labels_ # the labels from kmeans clustering

y = df_17_model2['HighUnemployment']
X = df_17_model2[['Employed','Poverty','MeanCommute','VotingAgeCitizen']]
X = np.column_stack((X,pd.get_dummies(newfeature)))

acc = cross_val_score(clf,X,y=y,cv=cv)

print ("Average accuracy (with kmeans for 'White/Hispanic/Black/Poverty')= ", acc.mean()*100, "+-", acc.std()*100)
# Out:
# Average accuracy (with kmeans for 'White/Hispanic/Black/Poverty')=  69.88167272576987 +- 1.7800007635604926

# %% [markdown]
# We see that when we cluster the variables White, Hispanic, Black, and Poverty (which we saw to be fairly correlated above), and use one-hot encoding on the clusters produced as new variables for the RF model, the accuracy decreases slighlty from the baseline accuracy to 69.9%.

# %%
#Group 2 kmeans.
from sklearn.cluster import KMeans
import numpy as np
import pandas as pd


X2 = df_17_model2[['Employed','Service','MeanCommute','VotingAgeCitizen']]

cls = KMeans(n_clusters=4, init='k-means++',random_state=1)
cls.fit(X2)
newfeature = cls.labels_ # the labels from kmeans clustering

y = df_17_model2['HighUnemployment']
X = df_17_model2[['White','Hispanic','Black','Poverty']]
X = np.column_stack((X,pd.get_dummies(newfeature)))

acc = cross_val_score(clf,X,y=y,cv=cv)

print ("Average accuracy (with kmeans for 'Employed/Service/MeanCommute/VotingAgeCitizen')= ", acc.mean()*100, "+-", acc.std()*100)
# Out:
# Average accuracy (with kmeans for 'Employed/Service/MeanCommute/VotingAgeCitizen')=  68.6674991426471 +- 2.187147312261757

# %% [markdown]
# When we clustered the remaining variables of Employed, Service, MeanCommute, and VotingAgeCitizen and use those clusters as variables in a Random Forest model, the accuracy decreases to 68.7%.

# %% [markdown]
# #### Kmeans clustering - Combining the two models

# %%
# Combined clustering code
### get the first clustering
cls_aff = KMeans(n_clusters=4, init='k-means++',random_state=1)
cls_aff.fit(X1)
newfeature_aff = cls_aff.labels_ # the labels from kmeans clustering

# append on the second clustering
cls_rev = KMeans(n_clusters=4, init='k-means++',random_state=1)
cls_rev.fit(X2)
newfeature_rev = cls_rev.labels_ # the labels from kmeans clustering

y = df_17_model2['HighUnemployment']
X = df_17_model2[['Employed','Service','MeanCommute','VotingAgeCitizen']]

X = np.column_stack((X,pd.get_dummies(newfeature_aff),pd.get_dummies(newfeature_rev)))

acc = cross_val_score(clf,X,y=y,cv=cv)

print ("Average accuracy for combined = ", acc.mean()*100, "+-", acc.std()*100)
# Out:
# Average accuracy for combined =  69.83639111937954 +- 1.9140559522134313

# %% [markdown]
# We see that the model prediction has improved marginally by combining the clustering models (kmeans).
# We will test the best number of clusters for each by grouping X1 and X2 respectively as in the code below:

# %%
X1 = df_17_model2[['White','Hispanic','Black','Poverty']]
X2 = df_17_model2[['Employed','Service','MeanCommute','VotingAgeCitizen']]
params = []
for n_aff in range(2,6):
    for n_rev in range(2,6):
        # get the first clustering
        cls_aff = KMeans(n_clusters=n_aff, init='k-means++',random_state=1)
        cls_aff.fit(X1)
        newfeature_aff = cls_aff.labels_ # the labels from kmeans clustering

        # append on the second clustering
        cls_rev = KMeans(n_clusters=n_rev, init='k-means++',random_state=1)
        cls_rev.fit(X2)
        newfeature_rev = cls_rev.labels_ # the labels from kmeans clustering

        y = df_17_model2['HighUnemployment']
        X = df_17_model2[['Employed','Service','MeanCommute','VotingAgeCitizen']]
        X = np.column_stack((X,pd.get_dummies(newfeature_aff),pd.get_dummies(newfeature_rev)))
        acc = cross_val_score(clf,X,y=y,cv=cv)
        params.append((n_aff,n_rev,acc.mean()*100,acc.std()*100)) # save state

        print ("Clusters",n_aff,n_rev,"Average accuracy = ", acc.mean()*100, "+-", acc.std()*100)
# Out:
# Clusters 2 2 Average accuracy =  69.3561946158029 +- 1.7797053263505007
# Clusters 2 3 Average accuracy =  69.27249557191794 +- 1.9034842629922684
# Clusters 2 4 Average accuracy =  69.34110168776684 +- 1.8912108790388034
# Clusters 2 5 Average accuracy =  69.3342482470344 +- 1.8855888333908504
# Clusters 3 2 Average accuracy =  69.14630508512703 +- 1.9613035560944365
# Clusters 3 3 Average accuracy =  69.19022266673103 +- 1.9355507910505065
# Clusters 3 4 Average accuracy =  69.26430351561464 +- 2.010039735812094
# Clusters 3 5 Average accuracy =  69.21352854131888 +- 2.038373617673871
# Clusters 4 2 Average accuracy =  69.75133294533916 +- 1.9185460859836707
# Clusters 4 3 Average accuracy =  69.7993510711439 +- 1.8294851711144964
# Clusters 4 4 Average accuracy =  69.83639111937954 +- 1.9140559522134313
# Clusters 4 5 Average accuracy =  69.89537584217777 +- 1.9057600078016195
# Clusters 5 2 Average accuracy =  69.98319763951875 +- 2.1870570273428127
# ...

# %% [markdown]
# Hyperparameter tuning for the best model prediction is done with iterations as above. We found that when using K-means to cluster sets of 4 features, creating 5 clusters for each of those clusterings results in the best accuracy of 70%. This still does not perform as well as the original baseline Random Forest model. We will now attempt DBSCAN to perform clustering to compare.

# %% [markdown]
# #### Clustering using DBSCAN
# DBSCAN is density based spatial clustering which will also include noise in the algorithm unlike kmeans clustering for machine learning. DBSCAN groups the points together that are close to one another by using the Euclidean distance measure. It also uses a parameter called the minimum number of points that would make it a dense cluster. The outliers are points in the low-density regions. The parameters used are eps (distance between two points lower are equal and considered neighbor), and minPoints (the minimum number of points to be considered to call it a dense cluster).
#
# It categorizes data points into three groups:
#
# - Core Point: If a point has more than Minpoints points in eps it is a Core point.
# - Border Point: If a point has fewer than MinPoints within eps but it is in the neighborhood of a core point then it is called a Border point.
# - Noise or outlier: A point which is neither a core point nor border point.
#
# We will use DBSCAN clustering to deteremine if the accuracy can be improved in our model.

# %%
# %%time 
# %%time

from sklearn.cluster import AgglomerativeClustering
from sklearn.cluster import DBSCAN

X1 = df_17_model2[['White','Hispanic','Black','Poverty']]
#X2 = df_17_model2[['Employed','Service','MeanCommute','VotingAgeCitizen']]

params = []
for eps in [0.1, 0.125, 0.15]:
    for mpts in range(14,15):

        # append on the clustering
        cls_aff = DBSCAN(eps=eps, min_samples=mpts)
        cls_aff.fit(X1)
        newfeature_aff = cls_aff.labels_ # the labels from kmeans clustering

        y = df_17_model2['HighUnemployment']
        X = df_17_model2[['Employed','Service','MeanCommute','VotingAgeCitizen']]
        X = np.column_stack((X,pd.get_dummies(newfeature_aff)))

        acc = cross_val_score(clf,X,y=y,cv=cv)
       # params.append((n_fare,n_fam,acc.mean()*100,acc.std()*100)) # save state

        print (eps,mpts,"Average accuracy DBSCAN = ", acc.mean()*100, "+-", acc.std()*100)
# Out:
# 0.1 14 Average accuracy DBSCAN =  67.11310848403951 +- 2.1944811760009633
# 0.125 14 Average accuracy DBSCAN =  67.11310848403951 +- 2.1944811760009633
# 0.15 14 Average accuracy DBSCAN =  67.11310848403951 +- 2.1944811760009633
# Wall time: 9min 10s
# Wall time: 9min 10s

# %% [markdown]
# #### DBSCAN inference
# Here we see the accuracy has decreases further and hence we see that K-means is a better clustering method in this situation. Overall, however, including clusters as variables in our predictive models did not produce an advantage over the original Random Forest model.

# %% [markdown]
# # Deployment

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Rubric 5:</b> Be critical of your performance and tell the reader how you current model might be usable by other parties. Did you achieve your goals? If not, can you reign in the utility of your modeling?
#
# - How useful is your model for interested parties (i.e., the companies or organizations that might want to use it)?
# - How would your deploy your model for interested parties?
# - What other data should be collected?
# - How often would the model need to be updated, etc.?
# </div>

# %% [markdown]
# We believe our models could be fairly useful for interested parties, who would likely be philanthropic organizations seeking to bring economic development or aid to areas in need. Some of our pure clustering methods achieved some decent metrics in homogeneity and silhouette scores, for example. The clusterings that these produced could be useful for targeting similar areas in need. If aid was brought to a few neighborhoods in a certain cluster, that type of aid could be assumed to have similar effectiveness in other members of that cluster. Future work could explore geographic similarity within the clusters as well, which could be very useful for these organizations.
#
# Our predictive Random Forest models using clusters to reduce dimensionality achieved decent accuracy levels, though not as good as the baseline RF model without clustering. Our goal was to improve the model's performance, but we did not achieve this. However, using clusters as new variables did not significantly decrease the accuracy, which is notable. In the future we could further tune parameters to attempt improvement, but until then the original Random Forest model would be useful and sufficient for an organization when wanting to predict unemployment or child poverty.
#
# The process of deploying our model would be somewhat dependent on the organization we were deploying it for. This is because they may want to use our models to predict unemployment or child poverty on their own data, but they may not have as many predictor variables as we used to train our models. Thus we would trim down our training sets and models based on the data we knew would be coming in. Beyond this, however, deploying our models might involve setting up a server and then setting up endpoints so that the company could make API requests to predict data points individually or in batches.
#
# Another option might be to use an existing service such as Deep Cognition (reference below) to host our models. This would require additional research and possibly more expenses, but would likely require less technical knowledge of setting up a server, endpoints, etc. which might be a limiting factor.
#
# The source of our data from was only a subset of the available attributes recorded by the U.S. government. We could retrieve additional features to make the deployed models even more generalized to the data that interested parties might have. In addition, the models should be updated every few years (say, every 5-10 years) to remain current. This works well with the U.S. census data that we trained our models on, since they are taken every 10 years but yearly estimates are published as well.

# %% [markdown]
# # Exceptional Work

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Rubric 6:</b> You have free reign to provide additional analyses or combine analyses.
# </div>

# %% [markdown]
# After examining exploratory plots and relationships between variables, it is apparent that there are potential underlying factors or variables that drive the levels of Unemployment and Child Poverty rate. There is an opportunity to examine the economic differences between Men and Women, and their respective employment positions, i.e. Professional, Office, Service, Construction, Production, and Public Work or Private Work. We will now perform a principal component analysis, aiming to perform dimension reduction as well as find a relationship between the different demographic and/or racial groups and their respective professional groups.

# %% [markdown]
# Besides PCA as a technique to create "new" features from existing variables, there are several additional features we could add or create. As we have done below, converting the Men and Women variables into percentages of the total population may be helpful to keep the measurements across census tracts consistent. This could also be done for the count variables of VotingAgeCitizen and Employed. It may also be helpful to divide up the states into their geographical regions such as the South, Midwest, etc, so that the predictive model does not have to create encodings for all of the states. In addition, if data is available it would be useful for us to add in a feature for the child population of the census tracts, so we could take child percentages into account when considering child poverty rates. We now continue with PCA.

# %% [markdown]
# #### Create New Features:

# %%
#New features for PCA analysis
df_17_cln['Men_perc'] = df_17_cln['Men'] / (df_17_cln['Men'] + df_17_cln['Women'])
df_17_cln['Women_perc'] = df_17_cln['Women'] / (df_17_cln['Men'] + df_17_cln['Women'])
df_17_cln['Employed_thousands'] = df_17_cln['Employed'] / 1000
df_17_cln['Income_thousands'] = df_17_cln['Income'] / 1000

# %% [markdown]
# We have created the above new features to create a meaningful subset of features to perform a PCA. Now let's rebuild the dataframe with new features.

# %% [markdown]
# #### Rebuild the dataframe with new features:

# %%
# create a subset of plottable features:
features_plot = ['Women_perc', 
                 'Income_thousands', 
                 'Professional', 
                 'Service', 
                 'Office', 
                 'Construction', 
                 'Production', 
                 'Drive', 
                 'Carpool', 
                 'Transit', 
                 'Walk', 
                 'OtherTransp', 
                 'WorkAtHome', 
                 'MeanCommute', 
                 'Employed_thousands', 
                 'PrivateWork', 
                 'PublicWork', 
                 'SelfEmployed', 
                 'FamilyWork']

cluster_plot_df = df_17_cln[features_plot]

# %%
cluster_plot_df.head()
# Out:
#             Women_perc  Income_thousands  Professional  Service  Office  \
# TractId
# 1001020100    0.512737            67.826          38.5     15.6    22.8
# 1001020200    0.462707            41.287          30.5     24.9    22.9
# 1001020300    0.547120            46.806          27.9     19.4    33.3
# 1001020400    0.531052            55.895          29.0     16.6    25.8
# 1001020500    0.492825            68.143          48.8     13.8    20.5
#
#             Construction  Production  Drive  Carpool  Transit  Walk  \
# TractId
# 1001020100          10.8        12.4   94.2      3.3      0.0   0.5
# 1001020200           6.3        15.4   90.5      9.1      0.0   0.0
# 1001020300           9.9         9.6   88.3      8.4      0.0   1.0
# 1001020400           9.1        19.5   82.3     11.2      0.0   1.5
# 1001020500           3.5        13.4   86.9     11.2      0.0   0.8
#
#             OtherTransp  WorkAtHome  MeanCommute  Employed_thousands  \
# TractId
# ...

# %%
cluster_plot_df.columns
# Out:
# Index(['Women_perc', 'Income_thousands', 'Professional', 'Service', 'Office',
#        'Construction', 'Production', 'Drive', 'Carpool', 'Transit', 'Walk',
#        'OtherTransp', 'WorkAtHome', 'MeanCommute', 'Employed_thousands',
#        'PrivateWork', 'PublicWork', 'SelfEmployed', 'FamilyWork'],
#       dtype='object')

# %% [markdown]
# Principal component analysis is a fast and flexible unsupervised method for dimensionality reduction in data. It is a statistical technique to convert high dimensional data to low dimensional data by selecting the most important features that capture maximum information about the dataset. The features are selected on the basis of variance that they cause in the output. The feature that causes highest variance is the first principal component. The feature that is responsible for second highest variance is considered the second principal component, and so on. Now let's implement PCA with the help of Python's Scikit-Learn library.

# %%
#- PCA transform components
from sklearn.decomposition import PCA

X = cluster_plot_df

pca = PCA(n_components=19)
pca.fit(X) # fit data and then transform it
X_pca = pca.transform(X)

# print the components

print ('pca:', pca.components_)
# Out:
# pca: [[-4.26073733e-05  8.98775019e-01  3.71876179e-01 -1.52146277e-01
#   -1.84936422e-02 -7.04677994e-02 -1.30764824e-01  1.56289564e-02
#   -5.05122360e-02  8.04710697e-03 -1.68119070e-02 -5.48887284e-03
#    4.91218707e-02  4.74288691e-02  1.03413011e-02 -1.63722040e-02
#    5.58524874e-03  1.06765029e-02  1.11410511e-04]
#  [ 6.49956465e-05 -2.55156292e-02  7.20349406e-02  1.07240504e-01
#   -4.08994218e-02 -6.25350751e-02 -7.58348123e-02 -7.76921840e-01
#   -1.59054927e-04  5.67609991e-01  1.45965197e-01  4.13267501e-02
#    2.21719474e-02  1.46057339e-01 -4.14722067e-03  1.66247560e-02
#   -1.97936123e-02  3.57657187e-03 -3.97824232e-04]
#  [ 1.35268614e-04 -3.20465123e-01  5.81169945e-01 -1.16110240e-01
#   -5.61839709e-02 -1.29909809e-01 -2.78933056e-01 -2.05925191e-03
#   -1.03034074e-01 -8.37697388e-02  1.07519157e-01  2.16024899e-02
#    5.97198306e-02 -1.75375720e-01 -9.26937068e-03 -4.64449438e-01
#    4.06512733e-01  5.64205783e-02  1.51447991e-03]
# ...

# %% [markdown]
# These are all the principal components of our dataset. Now let's find out how much variance does each principal component contributes.

# %%
#Finding variance by each component addition
for dimension in range(X_pca.shape[1]):
    variance = pca.explained_variance_ratio_[:dimension].sum() * 100.0
    print("PCA with %d components retains: %.3f of variance" % (dimension,variance))
# Out:
# PCA with 0 components retains: 0.000 of variance
# PCA with 1 components retains: 57.077 of variance
# PCA with 2 components retains: 75.249 of variance
# PCA with 3 components retains: 82.247 of variance
# PCA with 4 components retains: 87.084 of variance
# PCA with 5 components retains: 89.999 of variance
# PCA with 6 components retains: 92.358 of variance
# PCA with 7 components retains: 94.163 of variance
# PCA with 8 components retains: 95.897 of variance
# PCA with 9 components retains: 97.138 of variance
# PCA with 10 components retains: 98.186 of variance
# PCA with 11 components retains: 99.153 of variance
# PCA with 12 components retains: 99.623 of variance
# PCA with 13 components retains: 99.931 of variance
# PCA with 14 components retains: 99.986 of variance
# PCA with 15 components retains: 100.000 of variance
# PCA with 16 components retains: 100.000 of variance
# PCA with 17 components retains: 100.000 of variance
# PCA with 18 components retains: 100.000 of variance

# %% [markdown]
# From the output above, just two components contribute to 75% of the variance.

# %%
#Identifying number of PCA components for optimal preddiction
k = 0
total_variance = pca.explained_variance_.sum()
var_till_now = 0;

while (var_till_now/total_variance) < 0.99 :
    var_till_now += pca.explained_variance_[k]
    k = k + 1
    
print("Keeping variance = 99% of total variance , dimensions needed :",k)

k = 0;
var_till_now = 0;

while (var_till_now/total_variance) < 0.93 :
    var_till_now += pca.explained_variance_[k]
    k = k + 1
    
print("Keeping variance = 93% of total variance , dimensions needed :",k)
# Out:
# Keeping variance = 99% of total variance , dimensions needed : 11
# Keeping variance = 93% of total variance , dimensions needed : 7

# %% [markdown]
# If we want to retain 93% of total variance we will need about 6 or 7 components. But let's also use a scree plot to verify the principal components to keep. An ideal curve should be steep, then bends at an “elbow” — this is the cutting-off point — and after that flattens out.

# %%
#Draw a scree plot
#Reference: https://stats.stackexchange.com/questions/12819/how-to-draw-a-scree-plot-in-python
sns.set_style("darkgrid")
fig = plt.figure(figsize=(7,7))
var = pca.explained_variance_
num = [i+1 for i in range(len(var))]

plt.plot(num, var, 'ro-', linewidth=2)
plt.title('Scree Plot')
plt.xlabel('Principal Component')
plt.ylabel('Eigenvalue')

plt.show()

# %% [markdown]
# From the Scree plot above, about 6 or 7 is the cutting-off point and the curve flattens out. For our analysis, we decided to keep 7 components that explains 94% of the total variance.

# %%
#Match the labels of components
pc = pca.components_[:10]
pc = pd.DataFrame(pc)
pc.columns = cluster_plot_df.columns.values
pc.head();

# %% [markdown]
# We have matched the labels to the components. To investigate which predictor variables contribute most to the first 10 principal components, we list the ones that contribute over 20% below:

# %%
for i in range(len(pc)):
    pc1 = pc.iloc[i]
    print('component {}:\n {}\n'.format(i+1,pc1[abs(pc1)>=0.2]))
# Out:
# component 1:
#  Income_thousands    0.898775
# Professional        0.371876
# Name: 0, dtype: float64
#
# component 2:
#  Drive     -0.776922
# Transit    0.567610
# Name: 1, dtype: float64
#
# component 3:
#  Income_thousands   -0.320465
# Professional        0.581170
# Production         -0.278933
# PrivateWork        -0.464449
# PublicWork          0.406513
# Name: 2, dtype: float64
#
# component 4:
#  Income_thousands    0.226010
# Professional       -0.454263
# Construction        0.225580
# MeanCommute         0.223452
# PrivateWork        -0.577045
# PublicWork          0.489931
# Name: 3, dtype: float64
#
# component 5:
#  Office        -0.239021
# Drive         -0.378228
# Carpool        0.290850
# Transit       -0.478869
# Walk           0.338801
# MeanCommute   -0.511535
# Name: 4, dtype: float64
#
# component 6:
#  Service         0.612513
# Office          0.376053
# Construction   -0.333503
# Production     -0.478633
# MeanCommute    -0.226274
# Name: 5, dtype: float64
# ...

# %% [markdown]
# Each of the principal components above have multiple predictor variables, and only a few of them have one or two dominant variables, while most of them consist of equally important variables.

# %%
var_explained = np.cumsum(pca.explained_variance_ratio_)
num_comp = sum(var_explained < 0.95)
print (num_comp)
var_explained[:num_comp]
# Out:
# 7
# array([0.57077424, 0.75249072, 0.82246759, 0.87084153, 0.89999009,
#        0.92358221, 0.94162529])

# %%
pca.components_.shape
# Out:
# (19, 19)

# %%
#Compute the norms of each feature in the new space
n = X.shape[1]
norms = np.zeros(n)
for i in range(n):
    norms[i] = np.linalg.norm(pca.components_[:num_comp,i])**2
norms
# Out:
# array([2.36111922e-06, 9.90180924e-01, 7.52356112e-01, 7.04649569e-01,
#        7.06814606e-01, 2.40743327e-01, 4.07719301e-01, 7.88597478e-01,
#        1.28157020e-01, 5.95661967e-01, 1.82105937e-01, 1.15238539e-02,
#        4.40138600e-02, 4.30081309e-01, 4.73141934e-04, 5.57142743e-01,
#        4.16253266e-01, 4.34502856e-02, 7.29398780e-05])

# %%
# Get the most important features
norm_list = list(norms)
pca_feature_list = set()
for idx in sorted(norms,reverse=True)[:num_comp]:
    print (X.columns[norm_list.index(idx)],'-',idx)
    pca_feature_list.add(X.columns[norm_list.index(idx)])
# Out:
# Income_thousands - 0.990180923619683
# Drive - 0.7885974782204629
# Professional - 0.7523561121692625
# Office - 0.706814605880602
# Service - 0.7046495688234145
# Transit - 0.5956619669961812
# PrivateWork - 0.5571427431691991

# %%
pca_top_better_demo = X[list(pca_feature_list)]
pca_top_better_demo.head()
# Out:
#             Office  Income_thousands  Transit  PrivateWork  Professional  \
# TractId
# 1001020100    22.8            67.826      0.0         74.2          38.5
# 1001020200    22.9            41.287      0.0         75.9          30.5
# 1001020300    33.3            46.806      0.0         73.3          27.9
# 1001020400    25.8            55.895      0.0         75.8          29.0
# 1001020500    20.5            68.143      0.0         71.4          48.8
#
#             Service  Drive
# TractId
# 1001020100     15.6   94.2
# 1001020200     24.9   90.5
# 1001020300     19.4   88.3
# 1001020400     16.6   82.3
# 1001020500     13.8   86.9

# %%
# Using the elbow method to get the optimal number of clusters for K-Means clustering
from sklearn.cluster import KMeans
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state = 42)
    kmeans.fit(pca_top_better_demo)
    wcss.append(kmeans.inertia_)
plt.plot(range(1, 11), wcss)
plt.title('The Elbow Method showing the optimal K')
plt.xlabel('K - Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %% [markdown]
# The elbow method suggests an optimal number of clusters at 2 or 4. Now let's confirm the optimal K using hyperparameter tuning.

# %%
# Hyperparameter Tuning
parameters = {'n_clusters': [2, 3, 4, 5, 6]}
parameter_grid = ParameterGrid(parameters)
list(parameter_grid)
# Out:
# [{'n_clusters': 2},
#  {'n_clusters': 3},
#  {'n_clusters': 4},
#  {'n_clusters': 5},
#  {'n_clusters': 6}]

# %%
best_score = -1
model = KMeans()
for g in parameter_grid:
    model.set_params(**g)
    model.fit(pca_top_better_demo)

    ss = metrics.silhouette_score(pca_top_better_demo, model.labels_)
    print('Parameter: ', g, 'Score: ', ss)
    if ss > best_score:
        best_score = ss
        best_grid = g
# Out:
# Parameter:  {'n_clusters': 2} Score:  0.4255151496700121
# Parameter:  {'n_clusters': 3} Score:  0.27484686873254804
# Parameter:  {'n_clusters': 4} Score:  0.3118808293239068
# Parameter:  {'n_clusters': 5} Score:  0.2606901560429324
# Parameter:  {'n_clusters': 6} Score:  0.22567975725092765

# %%
best_grid
# Out:
# {'n_clusters': 2}

# %% [markdown]
# We see that the optimal number of clusters is 2. This is an intuitive result, because our target variables of unemployment and child poverty were created to be binary variables.

# %%
plt_pcl = PCA(n_components=3)
fe_pd_2d = plt_pcl.fit_transform(pca_top_better_demo)

# %%
from sklearn.cluster import KMeans
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize=(15,10)).gca(projection='3d')

fe_pd_2d_df = pd.DataFrame(fe_pd_2d, columns=['x','y','z'])

km_mdl = KMeans(n_clusters=2)
fe_pd_2d_df['clust'] = km_mdl.fit_predict(pca_top_better_demo)

c = {0: '#FF0000', 
     1: '#FFFF00',
     2: '#008000',
     3: '#0000FF',
     4: '#FF00FF',
     5: '#00FFFF',
     6: '#FFC0CB',
     7: '#00FF00',
     8: '#FFFFFF',
     9: '#FFA500'}

# cluster 0 is red 
# cluster 1 is yellow #FFFF00
# cluster 2 is dark green #008000
# cluster 3 is dark blue #0000FF
# cluster 4 is fuchsia #FF00FF
# cluster 5 is aqua #00FFFF
# cluster 6 is pink #FFC0CB
# cluster 7 is lime (0,1,0) #00FF00
# cluster 8 is white #FFFFFF
# cluster 9 is orange #FFA500

# web colors https://en.wikipedia.org/wiki/Web_colors

lama = pd.DataFrame(data = fe_pd_2d_df['clust'])
lama.clust.apply(lambda x: c[x])

fig.scatter(fe_pd_2d_df['x'], fe_pd_2d_df['y'], fe_pd_2d_df['z'], c=lama.clust.apply(lambda x: c[x]))
fig.patch.set_facecolor('white')
#ax = plt.subplot(111)
ax = plt.gca()
#ax.set_axis_bgcolor('white')
ax.set_facecolor('white')


ax.w_xaxis.set_pane_color((1.0, 1.0, 1.0, 1.0))
ax.w_yaxis.set_pane_color((1.0, 1.0, 1.0, 1.0))
ax.w_zaxis.set_pane_color((1.0, 1.0, 1.0, 1.0))
ax.w_xaxis.set_label_text('X axis', fontsize = 20);
ax.w_yaxis.set_label_text('Y axis', fontsize = 20);
ax.w_zaxis.set_label_text('Z axis', fontsize = 20);

# %% [markdown]
# Here we see the two clusters in three dimensions, which is the highest we can easily visualize. They appear to be well separated.

# %%
order_centroids = km_mdl.cluster_centers_.argsort()[:, ::-1]
for clust in range(km_mdl.n_clusters):
    print ("Cluster %d:" % clust)
    for feat in sorted(pca_top_better_demo.columns[order_centroids[clust, :8]].values.tolist()):
        print ('    ', feat)
    print
# Out:
# Cluster 0:
#      Drive
#      Income_thousands
#      Office
#      PrivateWork
#      Professional
#      Service
#      Transit
# Cluster 1:
#      Drive
#      Income_thousands
#      Office
#      PrivateWork
#      Professional
#      Service
#      Transit

# %% [markdown]
# From the dendrogram below, we see how the heirarchical clusters are composed. The links between variables indicate a cluster merge, and a vertical line could be drawn in various positions on the graph to create actual clusters. The number of lines intersected indicate the number of clusters that would be created, so we have control over the granuality of the clustering.

# %%
from scipy.cluster.hierarchy import linkage,dendrogram
import matplotlib as mpl
hclust = linkage(pca_top_better_demo.T,method='ward');
mpl.rcParams['figure.figsize'] = 10,10;
dendrogram(hclust, orientation='left', labels=pca_top_better_demo.columns);
ax = plt.gca()
ax.tick_params(axis='y', which='major', labelsize=15)
plt.savefig('pca_tree.png', bbox_inches='tight')

# %% [markdown]
# #### References
#
# 1. https://towardsdatascience.com/deploying-deep-learning-models-e9e4d7dda3ff
# 2. https://scikit-learn.org/stable/modules/clustering.html#homogeneity-completeness-and-v-measure
# 3. https://github.com/mGalarnyk/DSE220_Machine_Learning/blob/master/IPynb/4_Clustering.ipynb
# 4. http://people.csail.mit.edu/kjhsiao/Frey2007.pdf
